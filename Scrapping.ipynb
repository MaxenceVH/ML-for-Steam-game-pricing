# %%
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from random import uniform
from datetime import datetime

# %% [markdown]
# ## Scrapping of one game :

# %%
urls = 'https://store.steampowered.com/app/730/CounterStrike_Global_Offensive/'

page = requests.get(urls, headers = {"Accept-Language": "en-US"})
bs = BeautifulSoup(page.text, 'html.parser')

# Find name
name_block = bs.find('div','apphub_AppName')
name = name_block.contents[0]
print(name)

# Find genres
genreblock = bs.find('div','details_block')
title = genreblock.findAll('a')

genres = ['Simulation', 'Sports', 'Action', 'Adventure', 'RPG', 'Strategy', 'Sports', 'Racing', 'Indie',
         'Free to Play', 'Massively Multiplayer', 'Casual', 'Early Access']

genre = []

for g in title:
    if g.contents[0] in genres:
        genre.append(g.contents[0])
        print(g.contents[0])

# Find rating
rating_block = bs.find('div', 'summary_section')
rating_span = rating_block.findAll('span','game_review_summary')
rating = rating_span[0].contents[0]
print(rating)


# Price
price = None

    # Case 1 : Discount
tr = bs.find('div', 'discount_original_price')
if tr:
    price = tr.text.strip()

    # Case 2 : No Discount
if not price:
    no_disc = bs.find('div', 'game_purchase_price price')
    if no_disc:
        price = no_disc.text.strip()

# In-App Purchases
inAppPurchase = False

cat_block = bs.find('div', 'game_area_features_list_ctn')
categor = cat_block.findAll('a')
for cat in categor:
    ok = cat.find('div', 'label')
    if 'In-App Purchases' in ok.contents[0]:
        inAppPurchase = True
print(inAppPurchase)

# DLC
has_DLC = False

dlc = bs.find('div', 'game_area_dlc_section')
if dlc:
    has_DLC = True
print(has_DLC)

# Release Date
release_date = 'N/A'

release_date_block = bs.find('div', class_='release_date')
if release_date_block:
    date_div = release_date_block.find('div', class_='date')
    release_date = date_div.text.strip() if date_div else 'N/A'
    release_date_obj = datetime.strptime(release_date, "%d %b, %Y")
print(release_date_obj)
# Out:
# Counter-Strike 2
# Action
# Very Positive
# True
# True
# 2012-08-21 00:00:00

# %% [markdown]
# ## Scraping most sold games

# %%
links = []
    
url = 'https://store.steampowered.com/search/?sort_by=&sort_order=0&filter=topsellers&supportedlang=english&page=1'

page = requests.get(url, headers = {"Accept-Language": "en-US"})
bs = BeautifulSoup(page.text, 'html.parser')
games = bs.find('div', 'search_results')
game_list = games.findAll('a')

for i in range(25):
    links.append(game_list[i]['href'])
randsleep = uniform(0.0,0.7)
time.sleep(randsleep)

print(links)
# Out:
# ['https://store.steampowered.com/app/1903340/Clair_Obscur_Expedition_33/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/730/CounterStrike_2/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1675200/Steam_Deck/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/3017860/DOOM_The_Dark_Ages/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/3241660/REPO/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1172470/Apex_Legends/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/2625420/Drive_Beyond_Horizons/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/2488370/Cash_Cleaner_Simulator/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/3164500/Schedule_I/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/2669320/EA_SPORTS_FC_25/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/236390/War_Thunder/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/281990/Stellaris/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1172710/Dune_Awakening/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/2623190/The_Elder_Scrolls_IV_Oblivion_Remastered/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1086940/Baldurs_Gate_3/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1158310/Crusader_Kings_III/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1085660/Destiny_2/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/230410/Warframe/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/381210/Dead_by_Daylight/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/553850/HELLDIVERS_2/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/2139460/Once_Human/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1604030/V_Rising/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/1222670/The_Sims_4/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/2426960/Summoners_War/?snr=1_7_7_7000_150_1', 'https://store.steampowered.com/app/233860/Kenshi/?snr=1_7_7_7000_150_1']

# %%
df = pd.DataFrame(columns=['gameId','Name', 'Price', 'Genres', 'Rating', 'hasDLC', 'inAppPurchases', 'Release Date'])

headers = {"Accept-Language": "en-US"}
cookies = {
    'birthtime': '568022401',
    'lastagecheckage': '1-January-1988'
}

for i in range(25):
    try:
        page = requests.get(links[i], headers=headers, cookies=cookies)
        bs = BeautifulSoup(page.text, 'html.parser')

        gameid = links[i].split('/')[4]

        # Name
        name_block = bs.find('div','apphub_AppName')
        name = name_block.contents[0] if name_block else "N/A"

        # Find genres
        genreblock = bs.find('div','details_block')
        title = genreblock.findAll('a')

        genres = ['Simulation', 'Sports', 'Action', 'Adventure', 'RPG', 'Strategy', 'Sports', 'Racing', 'Indie',
                'Free to Play', 'Massively Multiplayer', 'Casual', 'Early Access']
        genre = []

        for g in title:
            if g.contents[0] in genres:
                genre.append(g.contents[0])

        # Find rating
        rating_block = bs.find('div', 'summary_section')
        if rating_block:
            rating_span = rating_block.findAll('span','game_review_summary')
            rating = rating_span[0].contents[0]
        
        # Price
        price = None
        
            # Case 1 : Discount
        tr = bs.find('div', 'discount_original_price')
        if tr:
            price = tr.text.strip()

            # Case 2 : No Discount
        if not price:
            no_disc = bs.find('div', 'game_purchase_price price')
            if no_disc:
                price = no_disc.text.strip()

        # In-App Purchases
        inAppPurchase = False

        cat_block = bs.find('div', 'game_area_features_list_ctn')
        categor = cat_block.findAll('a')
        for cat in categor:
            ok = cat.find('div', 'label')
            if 'In-App Purchases' in ok.contents[0]:
                inAppPurchase = True

        # DLC
        has_DLC = False

        dlc = bs.find('div', 'game_area_dlc_section')
        if dlc:
            has_DLC = True

        # Release Date
        release_date = 'N/A'

        release_date_block = bs.find('div', class_='release_date')
        if release_date_block:
            date_div = release_date_block.find('div', class_='date')
            release_date = date_div.text.strip() if date_div else 'N/A'
            release_date_obj = datetime.strptime(release_date, "%d %b, %Y")
        
        row = {'gameId':[gameid],'Name':[name], 'Genres':[genre], 'Price':[price],'Rating':[rating], 'hasDLC':[has_DLC], 
            'inAppPurchases': [inAppPurchase], 'Release Date': [release_date_obj]}
        df = pd.concat([df,pd.DataFrame(row)])

        # Break
        randsleep = uniform(0.0,0.6)
        time.sleep(randsleep)

        # Break every 50 requests
        # if (i + 1) % 50 == 0:
        #     time.sleep(10)

    except Exception as e:
        print(f"Erreur sur le jeu {links[i]} : {e}")

df = df.reset_index(drop=True)
# Out:
# C:\Users\maxen\AppData\Local\Temp\ipykernel_30332\1714247473.py:80: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,pd.DataFrame(row)])
# Erreur sur le jeu https://store.steampowered.com/app/1675200/Steam_Deck/?snr=1_7_7_7000_150_1 : 'NoneType' object has no attribute 'findAll'

# %%
df.head()
# Out:
#     gameId                         Name         Price                  Genres  \
# 0  1903340  Clair Obscur: Expedition 33        49,99€           [Action, RPG]
# 1      730             Counter-Strike 2  Free To Play                [Action]
# 2  3017860          DOOM: The Dark Ages        79,99€                [Action]
# 3  3241660                     R.E.P.O.         9,75€  [Action, Early Access]
# 4  1172470                Apex Legends™  Free To Play     [Action, Adventure]
#
#                     Rating hasDLC inAppPurchases Release Date
# 0            Very Positive   True          False   2025-04-24
# 1            Very Positive   True           True   2012-08-21
# 2            Very Positive  False          False   2025-05-14
# 3  Overwhelmingly Positive  False          False   2025-02-26
# 4                    Mixed  False           True   2020-11-04

# %%
df.to_csv('./gamelist.csv')
